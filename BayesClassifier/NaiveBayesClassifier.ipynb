# %%
from src.experiments import ExperimentRunner

ExperimentRunner().run()
# Out:
# REPEATED EXPERIMENT
# accuracy: {'mean': 0.8137893593919653, 'std': 0.013004409781987546, 'min': 0.7926167209554832, 'max': 0.8349619978284474}
# precision: {'mean': 0.6903369905621506, 'std': 0.01550622004577335, 'min': 0.6641366223908919, 'max': 0.7175257731958763}
# recall: {'mean': 0.9578512396694215, 'std': 0.013185782858153524, 'min': 0.9228650137741047, 'max': 0.9752066115702479}
# f1: {'mean': 0.8022653748699602, 'std': 0.012042266816997809, 'min': 0.7817142857142857, 'max': 0.8214702450408401}
#
# K-FOLD CV
# accuracy: {'mean': 0.8154737289335788, 'std': 0.009075215349606883, 'min': 0.8010869565217391, 'max': 0.825}
# precision: {'mean': 0.6932385429776209, 'std': 0.012209927073969113, 'min': 0.6744186046511628, 'max': 0.7045454545454546}
# recall: {'mean': 0.9547691886215242, 'std': 0.008490248486874408, 'min': 0.9419889502762431, 'max': 0.9640883977900553}
# f1: {'mean': 0.8031440543225831, 'std': 0.007190396014055414, 'min': 0.7918088737201365, 'max': 0.8125727590221188}
# ...
